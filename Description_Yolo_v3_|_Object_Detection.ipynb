# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinavl3v3l/yolov3/blob/main/Description_Yolo_v3_%7C_Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !rm -rf yolov3  # IF you want latest code

# %% [markdown]
# # Github Project- Yolov3
# Project Link - https://github.com/Abhinavl3v3l/yolov3.git

# %%
# !git clone https://github.com/Abhinavl3v3l/yolov3.git
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 6945 (delta 2), reused 4 (delta 1), pack-reused 6935
# Receiving objects: 100% (6945/6945), 253.11 MiB | 42.77 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# Checking out files: 100% (14330/14330), done.

# %%
# !ls -l
# Out:
# total 12
# drwx------ 5 root root 4096 Oct 23 16:14 gdrive
# drwxr-xr-x 1 root root 4096 Oct 14 16:31 sample_data
# drwxr-xr-x 9 root root 4096 Oct 23 16:37 yolov3

# %%
# !cp gdrive/My\ Drive/Submission_TSAI/yolov3-spp-ultralytics.pt yolov3/weights/       #RUN  ONLY IF NEW SESSION AND GIT IS NOT CLONED

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %% [markdown]
# You need to be in yolov3 folder to execute commands.

# %%
# %cd ./yolov3/
# !ls -l
# Out:
# /content/yolov3
# total 588
# drwxr-xr-x 2 root root   4096 Oct 23 16:37  cfg
# drwxr-xr-x 6 root root   4096 Oct 23 16:37  data
# -rw-r--r-- 1 root root   7993 Oct 23 16:37  detect.py
# -rw-r--r-- 1 root root  21790 Oct 23 16:37  models.py
# drwxr-xr-x 2 root root   4096 Oct 23 16:37  output
# drwxr-xr-x 2 root root   4096 Oct 23 16:37  __pycache__
# -rw-r--r-- 1 root root    144 Oct 23 16:37  README.md
# -rw-r--r-- 1 root root 246121 Oct 23 16:37  results.json
# -rw-r--r-- 1 root root 226970 Oct 23 16:37  results.png
# -rw-r--r-- 1 root root  11406 Oct 23 16:37  test.py
# -rw-r--r-- 1 root root    885 Oct 23 16:37  ting
# -rw-r--r-- 1 root root  23222 Oct 23 16:37  train.py
# -rw-r--r-- 1 root root  12061 Oct 23 16:37 'ubdivisions=1'
# drwxr-xr-x 3 root root   4096 Oct 23 16:37  utils
# -rw-r--r-- 1 root root   1370 Oct 23 16:37  vim.exe.stackdump
# drwxr-xr-x 2 root root   4096 Oct 23 16:37  weights
# -rw-r--r-- 1 root root   3509 Oct 23 16:37  Yolov3.ipynb

# %%
# !python train.py --data data/customdata/custom.data --batch 20 --cache --cfg cfg/yolov3-custom.cfg --epochs 100 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=20, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-23 16:37:17.673995: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (2863 found, 131 missing, 38 empty, 0 duplicate, for 3032 images): 100% 3032/3032 [00:00<00:00, 7696.46it/s]
# Caching images (1.7GB): 100% 3032/3032 [00:21<00:00, 139.37it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --output out_out
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='out_out', save_txt=False, source='data/customdata/images', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/3591 data/customdata/images/01-prince-boots - Copy.jpg: 512x448 5 bootss, Done. (0.044s)
# image 2/3591 data/customdata/images/026f0ffddc.jpg: 384x512 1 masks, Done. (0.037s)
# image 3/3591 data/customdata/images/032620_LS_covid-masks_inline-680.jpg: 320x512 1 hardhats, 1 masks, Done. (0.033s)
# image 4/3591 data/customdata/images/046acbc8e1.jpg: 384x512 1 masks, Done. (0.037s)
# ...

# %%
Image(filename='out_out/101.jpg', width=400)

# %%
Image(filename='out_out/img002.jpg', width=600)

# %%
Image(filename='out_out/E33.jpg', width=600)

# %%
Image(filename='out_out/Fimg_024.jpg', width=600)
